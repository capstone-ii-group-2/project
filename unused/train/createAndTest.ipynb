# %%
/Users/jackgaither/desktop/capstone2/project/training_datasets/asl_alphabet_train/asl_alphabet_train/A
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-56416e063e8a> in <module>
#       3
#       4 plt.figure(figsize=(10,8))
# ----> 5 plt.plot(loss_log[2:])
#       6 plt.plot(acc_log)
#       7 plt.plot(np.ones(len(acc_log)), linestyle='dashed')
#
# NameError: name 'loss_log' is not defined

# %%
from PIL import Image
import numpy as np
import sys
import os
import csv


def createFileList(myDir, format='.jpg'):
    fileList = []
    print(myDir)
    for root, dirs, files in os.walk(myDir, topdown=False):
        for name in files:
            if name.endswith(format):
                fullName = os.path.join(root, name)
                fileList.append(fullName)
    return fileList
# load the original image
myFileList = createFileList('/Users/jackgaither/desktop/capstone2/project/training_datasets/asl_alphabet_train/asl_alphabet_train/A')
for file in myFileList:
    print(file)
    img_file = Image.open(file)

    # get original image parameters...
    width, height = img_file.size
    format = img_file.format
    mode = img_file.mode

     # Make image Greyscale
    img_grey = img_file.convert('L')
    value = np.asarray(img_grey.getdata(), dtype=np.int).reshape((img_grey.size[1], img_grey.size[0]))


    value = value.flatten()
    print(value)
    with open("img_pixels.csv", 'a') as f:
        writer = csv.writer(f)
        writer.writerow(value)
# Out:
# /Users/jackgaither/desktop/capstone2/project/training_datasets/asl_alphabet_train/asl_alphabet_train/A
# /Users/jackgaither/desktop/capstone2/project/training_datasets/asl_alphabet_train/asl_alphabet_train/A/A25.jpg
# [34 31 29 ... 29 30 30]
# /Users/jackgaither/desktop/capstone2/project/training_datasets/asl_alphabet_train/asl_alphabet_train/A/A2286.jpg
# [31 30 31 ... 29 27 30]
# /Users/jackgaither/desktop/capstone2/project/training_datasets/asl_alphabet_train/asl_alphabet_train/A/A1957.jpg
# [29 34 29 ... 28 27 32]
# /Users/jackgaither/desktop/capstone2/project/training_datasets/asl_alphabet_train/asl_alphabet_train/A/A618.jpg
# [33 30 30 ... 31 29 30]
# /Users/jackgaither/desktop/capstone2/project/training_datasets/asl_alphabet_train/asl_alphabet_train/A/A1943.jpg
# [34 33 29 ... 27 32 31]
# /Users/jackgaither/desktop/capstone2/project/training_datasets/asl_alphabet_train/asl_alphabet_train/A/A31.jpg
# [34 29 31 ... 30 30 29]
# ...
